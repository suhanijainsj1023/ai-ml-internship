# %%
# VARIABLES
name="suhani jain"
age=21
numbers=71.5
print(name)
print(age)
print(numbers)
# Out:
# suhani jain
# 21
# 71.5

# %%
# DATA TYPES
name="suhani jain"
age=21
numbers=71.5
eligible_for_voting=True
print(type(name))
print(type(age))
print(type(numbers))
print(type(eligible_for_voting))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# OPERATORS
a=10
b=5
print(a+b) 
print(a-b) 
print(a*b)
print(a/b)
print(a**b)
print(a%b)
# Out:
# 15
# 5
# 50
# 2.0
# 100000
# 0

# %%
# LOOPS
# 1. for loop
for i in range(11):
    print(i**2)

# 2. while loop
num=1
while num>10:
    print(num)
    num+=1
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
# 2. while loop
num=1
while num<10:
    print(num)
    num+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# FUNCTIONS
def add(a,b):
    return a+b

add(10,5)
# Out:
# 15

# %%
def mul(a,b):
    a=5
    b=2
    return a*b

mul(a,b)
# Out:
# 10
