# %%
import pandas as pd

# %%
df=pd.read_csv("cleaned_dataset.csv")
df
# Out:
#     ID    Name        Age       City   Salary Department   Join_Date
# 0   12  Suresh  28.000000    Chennai  61000.0    Finance  2022-04-04
# 1    5   Sneha  35.000000    Chennai  50000.0         IT  2023-05-05
# 2    6    Neha  27.666667       Pune  50000.0         IT  2021-08-19
# 3    1  Vikram  22.000000      Delhi  25000.0      Sales  2021-03-01
# 4   10   Karan  27.000000     Mumbai  50000.0         IT  2019-06-25
# 5    4   Sneha  30.000000    Chennai  45000.0  Marketing  2019-11-20
# 6    2   Pooja  25.000000     Mumbai  30000.0         IT  2020-07-15
# 7   11   Pooja  27.666667       Pune  52000.0         IT  2021-12-12
# 8    8   Pooja  19.000000      Delhi  80000.0      Sales  2022-09-30
# 9    3   Rohan  27.666667  Bangalore  50000.0         HR  2022-01-10
# 10   7    Neha  40.000000    Kolkata  75000.0    Finance  2020-02-14
# 11   9    Neha  23.000000    Chennai  28000.0         HR  2023-01-01

# %%
import matplotlib.pyplot as plt

# %%
# scatter plot
plt.figure()
plt.scatter(df["Age"], df["Salary"])
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary")
plt.show()

# %%
# bar chart
plt.figure()
df["Department"].value_counts().plot(kind="bar")
plt.title("Department Count")
plt.show()

# %%
# line chart
df_sorted = df.sort_values("Join_Date")
plt.figure()
plt.plot(df_sorted["Join_Date"], df_sorted["Salary"])
plt.xlabel("Join Date")
plt.ylabel("Salary")
plt.title("Salary Trend over Join Date")
plt.show()
