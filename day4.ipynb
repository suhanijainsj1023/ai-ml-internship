# %%
import pandas as pd

# %%
df=pd.read_csv("Book1.csv")
df
# Out:
#        NAME  AGE  SCORES
# 0    Sakshi   21      71
# 1     Suman   23      75
# 2     Nitin   18      70
# 3    Shreya   22      72
# 4      Neha   19      76
# 5     Parul   25      79
# 6  Abhishek   24      78

# %%
df.head()
# Out:
#      NAME  AGE  SCORES
# 0  Sakshi   21      71
# 1   Suman   23      75
# 2   Nitin   18      70
# 3  Shreya   22      72
# 4    Neha   19      76

# %%
df.tail(3)
# Out:
#        NAME  AGE  SCORES
# 4      Neha   19      76
# 5     Parul   25      79
# 6  Abhishek   24      78

# %%
df.shape
# Out:
# (7, 3)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        NAME  AGE  SCORES
# 0    Sakshi   21      71
# 1     Suman   23      75
# 2     Nitin   18      70
# 3    Shreya   22      72
# 4      Neha   19      76
# 5     Parul   25      79
# 6  Abhishek   24      78>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    7 non-null      object
#  1   AGE     7 non-null      int64
#  2   SCORES  7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df["SCORES"]=df["SCORES"]+1

# %%
df["SCORES"]
# Out:
# 0    72
# 1    76
# 2    71
# 3    73
# 4    77
# 5    80
# 6    79
# Name: SCORES, dtype: int64
