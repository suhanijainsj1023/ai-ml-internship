# %%
import numpy as np

# %%
# 1D array
a=np.array([1,2,3,4,5,6])
a
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# 2D array
b=np.array([[1,2,3],
           [4,5,6]])
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# #### indexing

# %%
a[0]
# Out:
# array([1, 2, 3])

# %%
a[2]
# Out:
# 3

# %%
b[0,0]
# Out:
# 1

# %%
b[1,2]
# Out:
# 6

# %% [markdown]
# #### slicing

# %%
a[:3]
# Out:
# array([1, 2, 3])

# %%
a[1:3]
# Out:
# array([2, 3])

# %% [markdown]
# #### mathematical operators

# %%
a + 5
# Out:
# array([ 6,  7,  8,  9, 10, 11])

# %%
a*2
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %%
np.sum(a)
# Out:
# 21

# %%
np.mean(a)
# Out:
# 3.5

# %%
np.max(a)
# Out:
# 6

# %%
np.max(b)
# Out:
# 6

# %%
arr=np.array([1,2,3])
arr2=np.array([4,5,6])
r=np.sum((arr,arr2))
r
# Out:
# 21
